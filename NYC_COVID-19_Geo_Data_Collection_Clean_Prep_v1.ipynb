# %% [markdown]
# # NYC COVID-19 Cases - Data Collection, Exploring, Prepping, and Cleaning

# %% [markdown]
# ## Purpose:

# %% [markdown]
# #### Collect local NYC COVID-19 data (this notebook) and and plot by coordinates on a map (separate notebook)

# %% [markdown]
# ## Resources & References:

# %% [markdown]
# #### NYC Health COVID-19 Data - https://github.com/nychealth/coronavirus-data/blob/master/tests-by-zcta.csv
#
# #### ZCTA Code to Polygons Source - https://mydata.iowa.gov/Boundaries/ZIP-Code-Tabulation-Areas-ZCTAs-/4nkg-rrrc
#
# #### Zip Codes & FIPS (not used) - https://www.kaggle.com/danofer/zipcodes-county-fips-crosswalk/version/1#
#
# #### Geojson with FIPS (not used) - https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json

# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import plotly.offline as pyo
import plotly.graph_objs as go
import math
import geopandas

# %% [markdown]
# # Set local working directory

# %%
my_path = '/Users/Dave/Desktop/CODE/DBProjects/DBP0001_Local-COVID-Tracker/GitHub/'

# %% [markdown]
# # Read in Data from "NYC Health" & Inspect

# %%
df=pd.read_csv('https://raw.githubusercontent.com/nychealth/coronavirus-data/master/tests-by-zcta.csv')

print(df.head())

print('\n')

print(df.describe())

print('\n')

print(df.info())

print('\n')

print(df.dtypes)

print('\n Total Positive Cases to Date: ' + str(df['Positive'].sum()))
# Out:
#    MODZCTA  Positive  Total  zcta_cum.perc_pos
# 0      NaN      1844   2051              89.91
# 1  10001.0       254    563              45.12
# 2  10002.0       695   1325              52.45
# 3  10003.0       342    812              42.12
# 4  10004.0        24     62              38.71
#
#
#             MODZCTA     Positive        Total  zcta_cum.perc_pos
# count    177.000000   178.000000   178.000000         178.000000
# mean   10810.378531   723.466292  1286.707865          53.587472
# std      578.173317   505.132059   804.608775           9.531953
# min    10001.000000    14.000000    54.000000          25.930000
# 25%    10301.000000   348.750000   648.750000          46.807500
# 50%    11109.000000   589.500000  1101.500000          55.535000
# 75%    11361.000000  1042.500000  1891.500000          60.697500
# max    11697.000000  2749.000000  4079.000000          89.910000
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MODZCTA            177 non-null    float64
#  1   Positive           178 non-null    int64
#  2   Total              178 non-null    int64
#  3   zcta_cum.perc_pos  178 non-null    float64
# dtypes: float64(2), int64(2)
# memory usage: 5.7 KB
# None
#
#
# MODZCTA              float64
# Positive               int64
# Total                  int64
# zcta_cum.perc_pos    float64
# dtype: object
#
#  Total Positive Cases to Date: 128777

# %% [markdown]
# # Send Zip Codes to List, Convert to int (and remove NaN)

# %%
ziplist=df['MODZCTA'].tolist()
ziplistfix=[]

for i in ziplist:
    if math.isnan(i):
        continue
    else:
        ziplistfix.append(int(i))
        
print(ziplistfix)

print('\nTotal # of Zip Codes in NYC Health Dataframe: ' + str(len(ziplistfix)))
# Out:
# [10001, 10002, 10003, 10004, 10005, 10006, 10007, 10009, 10010, 10011, 10012, 10013, 10014, 10016, 10017, 10018, 10019, 10021, 10022, 10023, 10024, 10025, 10026, 10027, 10028, 10029, 10030, 10031, 10032, 10033, 10034, 10035, 10036, 10037, 10038, 10039, 10040, 10044, 10065, 10069, 10075, 10128, 10280, 10282, 10301, 10302, 10303, 10304, 10305, 10306, 10307, 10308, 10309, 10310, 10312, 10314, 10451, 10452, 10453, 10454, 10455, 10456, 10457, 10458, 10459, 10460, 10461, 10462, 10463, 10464, 10465, 10466, 10467, 10468, 10469, 10470, 10471, 10472, 10473, 10474, 10475, 11004, 11101, 11102, 11103, 11104, 11105, 11106, 11109, 11201, 11203, 11204, 11205, 11206, 11207, 11208, 11209, 11210, 11211, 11212, 11213, 11214, 11215, 11216, 11217, 11218, 11219, 11220, 11221, 11222, 11223, 11224, 11225, 11226, 11228, 11229, 11230, 11231, 11232, 11233, 11234, 11235, 11236, 11237, 11238, 11239, 11354, 11355, 11356, 11357, 11358, 11360, 11361, 11362, 11363, 11364, 11365, 11366, 11367, 11368, 11369, 11370, 11372, 11373, 11374, 11375, 11377, 11378, 11379, 11385, 11411, 11412, 11413, 11414, 11415, 11416, 11417, 11418, 11419, 11420, 11421, 11422, 11423, 11426, 11427, 11428, 11429, 11432, 11433, 11434, 11435, 11436, 11691, 11692, 11693, 11694, 11697]
#
# Total # of Zip Codes in NYC Health Dataframe: 177

# %% [markdown]
# # Collect Polygon/Geo Coordinate Data for ZCTA Codes from "Iowa.Gov"

# %% [markdown]
# ### Download CSV via: https://mydata.iowa.gov/Boundaries/ZIP-Code-Tabulation-Areas-ZCTAs-/4nkg-rrrc
# ### Read into Dataframe and inspect

# %%
df2=pd.read_csv(my_path+'ZIP_Code_Tabulation_Areas__ZCTAs_.csv')

# %%
###IF IN ZIP FORMAT

# import zipfile
# zf = zipfile.ZipFile(my_path+'ZIP_Code_Tabulation_Areas__ZCTAs_.csv.zip') 
# df2 = pd.read_csv(zf.open('ZIP_Code_Tabulation_Areas__ZCTAs_.csv'))

# %%
print(df2.head())

print('\n')

print(df2.describe())

print('\n')

print(df2.info)

print('\n')

print(df2.dtypes)
# Out:
#    ZCTA Code                                           the_geom  \
# 0      76565  MULTIPOLYGON (((-98.416145 31.663624, -98.4042...
# 1      32334  MULTIPOLYGON (((-84.884013 30.373846999999994,...
# 2      88310  MULTIPOLYGON (((-106.195761 32.746862, -106.17...
# 3      81040  MULTIPOLYGON (((-105.501286 37.598603, -105.49...
# 4      56560  MULTIPOLYGON (((-96.839548 47.006727999999995,...
#
#                                         polygon_geom  \
# 0  POLYGON ((-98.416145 31.663624, -98.40428 31.6...
# 1  POLYGON ((-84.884013 30.373846999999994, -84.8...
# 2  POLYGON ((-106.195761 32.746862, -106.176111 3...
# 3  POLYGON ((-105.501286 37.598603, -105.493273 3...
# 4  POLYGON ((-96.839548 47.006727999999995, -96.8...
#
#                                         centroid
# 0  POINT (-98.33188436718751 31.647865195312495)
# 1  POINT (-84.78215753320312 30.378027208984367)
# 2   POINT (-106.00594445800783 32.7774532685547)
# 3  POINT (-105.16623194042968 37.81005166894531)
# 4  POINT (-96.72933554882812 46.799505947265615)
#
#
#           ZCTA Code
# count  33144.000000
# mean   49668.659033
# std    27585.182370
# min      601.000000
# 25%    26622.500000
# 50%    49741.500000
# 75%    72131.250000
# max    99929.000000
#
#
# <bound method DataFrame.info of        ZCTA Code                                           the_geom  \
# 0          76565  MULTIPOLYGON (((-98.416145 31.663624, -98.4042...
# 1          32334  MULTIPOLYGON (((-84.884013 30.373846999999994,...
# 2          88310  MULTIPOLYGON (((-106.195761 32.746862, -106.17...
# 3          81040  MULTIPOLYGON (((-105.501286 37.598603, -105.49...
# 4          56560  MULTIPOLYGON (((-96.839548 47.006727999999995,...
# ...          ...                                                ...
# 33139      79094  MULTIPOLYGON (((-101.627507 34.865974, -101.62...
# 33140      61544  MULTIPOLYGON (((-90.328003 40.714119, -90.3202...
# 33141      11203  MULTIPOLYGON (((-73.947676 40.660297, -73.9426...
# 33142      68858  MULTIPOLYGON (((-99.425986 41.046471, -99.4091...
# 33143      29040  MULTIPOLYGON (((-80.54335999999999 34.011752, ...
#
#                                             polygon_geom  \
# 0      POLYGON ((-98.416145 31.663624, -98.40428 31.6...
# 1      POLYGON ((-84.884013 30.373846999999994, -84.8...
# 2      POLYGON ((-106.195761 32.746862, -106.176111 3...
# 3      POLYGON ((-105.501286 37.598603, -105.493273 3...
# 4      POLYGON ((-96.839548 47.006727999999995, -96.8...
# ...                                                  ...
# 33139  POLYGON ((-101.627507 34.865974, -101.627861 3...
# 33140  POLYGON ((-90.328003 40.714119, -90.320206 40....
# 33141  POLYGON ((-73.947676 40.660297, -73.942611 40....
# 33142  POLYGON ((-99.425986 41.046471, -99.409167 41....
# 33143  POLYGON ((-80.54335999999999 34.011752, -80.54...
#
#                                             centroid
# 0      POINT (-98.33188436718751 31.647865195312495)
# 1      POINT (-84.78215753320312 30.378027208984367)
# 2       POINT (-106.00594445800783 32.7774532685547)
# 3      POINT (-105.16623194042968 37.81005166894531)
# 4      POINT (-96.72933554882812 46.799505947265615)
# ...                                              ...
# 33139  POINT (-101.51720195703126 34.84004158984374)
# 33140   POINT (-90.24871345703126 40.67999852734374)
# 33141  POINT (-73.93544918749998 40.650487187500005)
# 33142     POINT (-99.378200984375 40.94791220312499)
# 33143   POINT (-80.39336875976564 34.11849808398437)
#
# [33144 rows x 4 columns]>
#
#
# ZCTA Code        int64
# the_geom        object
# polygon_geom    object
# centroid        object
# dtype: object

# %% [markdown]
# # Create new Dataframe where df2 is filtered to match Zip Codes in df

# %% [markdown]
# ### ...and rename "ZCTA Code" and "the_geom" columns

# %%
df_geomatch=df2[df2['ZCTA Code'].isin(ziplistfix)]

df_geomatch=df_geomatch.rename(columns={'the_geom': 'geometry'})

df_geomatch=df_geomatch.rename(columns={'ZCTA Code': 'ZCTA_Code'})

print(df_geomatch.head())

print('\n')

print(df_geomatch.describe())

print('\n')

print(df_geomatch.info)

df_geomatch_i = df_geomatch.index

df_geomatch_i_rowcount = len(df_geomatch_i)

print('\nNumber of rows in df_geomatch: ' + str(df_geomatch_i_rowcount))
# Out:
#       ZCTA_Code                                           geometry  \
# 380       10280  MULTIPOLYGON (((-74.01858899999999 40.712201, ...
# 989       11358  MULTIPOLYGON (((-73.807514 40.762178999999996,...
# 1879      11225  MULTIPOLYGON (((-73.96289399999999 40.663798, ...
# 1937      11221  MULTIPOLYGON (((-73.948185 40.690242, -73.9453...
# 1967      11411  MULTIPOLYGON (((-73.74864300000002 40.70158699...
#
#                                            polygon_geom  \
# 380   POLYGON ((-74.01858899999999 40.712201, -74.01...
# 989   POLYGON ((-73.807514 40.762178999999996, -73.8...
# 1879  POLYGON ((-73.96289399999999 40.663798, -73.96...
# 1937  POLYGON ((-73.948185 40.690242, -73.945349 40....
# 1967  POLYGON ((-73.74864300000002 40.70158699999999...
#
#                                            centroid
# 380    POINT (-74.01690924352604 40.71025141632766)
# 989       POINT (-73.79669671875001 40.76080428125)
# 1879  POINT (-73.95431249265435 40.663038155147255)
# 1937   POINT (-73.92605128125001 40.69324903124999)
# 1967       POINT (-73.7350738125 40.69432506249999)
#
#
#           ZCTA_Code
# count    177.000000
# mean   10810.378531
# std      578.173317
# min    10001.000000
# 25%    10301.000000
# 50%    11109.000000
# 75%    11361.000000
# max    11697.000000
#
#
# <bound method DataFrame.info of        ZCTA_Code                                           geometry  \
# 380        10280  MULTIPOLYGON (((-74.01858899999999 40.712201, ...
# 989        11358  MULTIPOLYGON (((-73.807514 40.762178999999996,...
# 1879       11225  MULTIPOLYGON (((-73.96289399999999 40.663798, ...
# 1937       11221  MULTIPOLYGON (((-73.948185 40.690242, -73.9453...
# 1967       11411  MULTIPOLYGON (((-73.74864300000002 40.70158699...
# ...          ...                                                ...
# 31824      10304  MULTIPOLYGON (((-74.12017399999999 40.58821599...
# 32557      11423  MULTIPOLYGON (((-73.781161 40.729213, -73.7775...
# 32669      11356  MULTIPOLYGON (((-73.858158 40.787034999999996,...
# 32726      11435  MULTIPOLYGON (((-73.82556699999999 40.71615099...
# 33141      11203  MULTIPOLYGON (((-73.947676 40.660297, -73.9426...
#
#                                             polygon_geom  \
# 380    POLYGON ((-74.01858899999999 40.712201, -74.01...
# 989    POLYGON ((-73.807514 40.762178999999996, -73.8...
# 1879   POLYGON ((-73.96289399999999 40.663798, -73.96...
# 1937   POLYGON ((-73.948185 40.690242, -73.945349 40....
# 1967   POLYGON ((-73.74864300000002 40.70158699999999...
# ...                                                  ...
# 31824  POLYGON ((-74.12017399999999 40.58821599999999...
# 32557  POLYGON ((-73.781161 40.729213, -73.777575 40....
# 32669  POLYGON ((-73.858158 40.787034999999996, -73.8...
# 32726  POLYGON ((-73.82556699999999 40.71615099999999...
# 33141  POLYGON ((-73.947676 40.660297, -73.942611 40....
#
#                                             centroid
# 380     POINT (-74.01690924352604 40.71025141632766)
# 989        POINT (-73.79669671875001 40.76080428125)
# 1879   POINT (-73.95431249265435 40.663038155147255)
# 1937    POINT (-73.92605128125001 40.69324903124999)
# 1967        POINT (-73.7350738125 40.69432506249999)
# ...                                              ...
# 31824   POINT (-74.09772625106777 40.59711801189746)
# 32557         POINT (-73.7781975 40.726738499999996)
# 32669   POINT (-73.84435509374998 40.78785178124999)
# 32726   POINT (-73.81549712500001 40.71218312499999)
# 33141  POINT (-73.93544918749998 40.650487187500005)
#
# [177 rows x 4 columns]>
#
# Number of rows in df_geomatch: 177

# %% [markdown]
# # Send df2 geometry/multipolygon series and polygon_geom/polygon series to separate lists to inspect full entries

# %% [markdown]
# ### ...and in case further manipulation is needed

# %%
multipoly_lst = pd.Series(df_geomatch.geometry.values,index=df_geomatch['ZCTA_Code']).to_dict()

poly_lst = pd.Series(df_geomatch.polygon_geom.values,index=df_geomatch['ZCTA_Code']).to_dict()

example_1 = multipoly_lst[10280]

example_2 = poly_lst[10280]

print(example_1)

print('\n')

print(example_2)
# Out:
# MULTIPOLYGON (((-74.01858899999999 40.712201, -74.016508 40.713224, -74.01736799999999 40.713378, -74.016198 40.714766999999995, -74.01359699999999 40.713623, -74.014697 40.709779, -74.015956 40.70668, -74.016131 40.706244, -74.017575 40.70684, -74.018008 40.705664999999996, -74.016628 40.704799, -74.015678 40.70125600000001, -74.0142519151327 40.7003146857495, -74.0168 40.701794, -74.0194854329352 40.70690774995101, -74.01858899999999 40.712201)))
#
#
# POLYGON ((-74.01858899999999 40.712201, -74.016508 40.713224, -74.01736799999999 40.713378, -74.016198 40.714766999999995, -74.01359699999999 40.713623, -74.014697 40.709779, -74.015956 40.70668, -74.016131 40.706244, -74.017575 40.70684, -74.018008 40.705664999999996, -74.016628 40.704799, -74.015678 40.70125600000001, -74.0142519151327 40.7003146857495, -74.0168 40.701794, -74.0194854329352 40.70690774995101, -74.01858899999999 40.712201))

# %% [markdown]
# # Send df_geomatch Dataframe to csv

# %%
df_geomatch.to_csv(my_path+'df_geomatch.csv')

# %% [markdown]
# # Import and use wkt and json module to create a geojson column in df_geomatch Dataframe and Inspect

# %%
from geomet import wkt
import json

#Apply function to create new column
df_geomatch["geojson"] = df_geomatch["polygon_geom"].apply(lambda x: json.dumps(wkt.loads(x)))

print(df_geomatch.head())

print('\n')

print(df_geomatch.dtypes)
# Out:
#       ZCTA_Code                                           geometry  \
# 380       10280  MULTIPOLYGON (((-74.01858899999999 40.712201, ...
# 989       11358  MULTIPOLYGON (((-73.807514 40.762178999999996,...
# 1879      11225  MULTIPOLYGON (((-73.96289399999999 40.663798, ...
# 1937      11221  MULTIPOLYGON (((-73.948185 40.690242, -73.9453...
# 1967      11411  MULTIPOLYGON (((-73.74864300000002 40.70158699...
#
#                                            polygon_geom  \
# 380   POLYGON ((-74.01858899999999 40.712201, -74.01...
# 989   POLYGON ((-73.807514 40.762178999999996, -73.8...
# 1879  POLYGON ((-73.96289399999999 40.663798, -73.96...
# 1937  POLYGON ((-73.948185 40.690242, -73.945349 40....
# 1967  POLYGON ((-73.74864300000002 40.70158699999999...
#
#                                            centroid  \
# 380    POINT (-74.01690924352604 40.71025141632766)
# 989       POINT (-73.79669671875001 40.76080428125)
# 1879  POINT (-73.95431249265435 40.663038155147255)
# 1937   POINT (-73.92605128125001 40.69324903124999)
# 1967       POINT (-73.7350738125 40.69432506249999)
#
#                                                 geojson
# 380   {"type": "Polygon", "coordinates": [[[-74.0185...
# 989   {"type": "Polygon", "coordinates": [[[-73.8075...
# 1879  {"type": "Polygon", "coordinates": [[[-73.9628...
# 1937  {"type": "Polygon", "coordinates": [[[-73.9481...
# 1967  {"type": "Polygon", "coordinates": [[[-73.7486...
#
#
# ZCTA_Code        int64
# geometry        object
# polygon_geom    object
# centroid        object
# geojson         object
# dtype: object

# %% [markdown]
# # Inspect a single df_geomatch geojson entry

# %%
df_geomatch.iloc[0,4]
# Out:
# '{"type": "Polygon", "coordinates": [[[-74.01858899999999, 40.712201], [-74.016508, 40.713224], [-74.01736799999999, 40.713378], [-74.016198, 40.714766999999995], [-74.01359699999999, 40.713623], [-74.014697, 40.709779], [-74.015956, 40.70668], [-74.016131, 40.706244], [-74.017575, 40.70684], [-74.018008, 40.705664999999996], [-74.016628, 40.704799], [-74.015678, 40.70125600000001], [-74.0142519151327, 40.7003146857495], [-74.0168, 40.701794], [-74.0194854329352, 40.70690774995101], [-74.01858899999999, 40.712201]]]}'

# %% [markdown]
# # Prep Dataframes for Merge

# %% [markdown]
# ### Drop NaN in original df, cast MODZCTA to int, make a copy of df (df_prefinal) and rename MODZCTA to ZCTA_Code... and make sure row count of df_prefinal matches length of df_geomatch

# %%
df.dropna(inplace=True)

df['MODZCTA']=df['MODZCTA'].astype(int)

df_prefinal = df

df_prefinal = df_prefinal.rename(columns={'MODZCTA': 'ZCTA_Code'})

df_prefinal_i = df_prefinal.index

df_prefinal_i_rowcount = len(df_prefinal_i)

print('\nNumber of rows in df_prefinal: ' + str(df_prefinal_i_rowcount))

if df_geomatch_i_rowcount == df_prefinal_i_rowcount:
    print('\nROW COUNTS MATCH!')
else:
    print('\nDouble check data. Row counts don\'t match')
# Out:
# Number of rows in df_prefinal: 177
#
# ROW COUNTS MATCH!

# %% [markdown]
# # Merge Dataframes df_geomatch and df_prefinal on ZCTA_Code & Inspect

# %%
df_final_merged = df_geomatch.merge(df_prefinal, how = 'inner', on = ['ZCTA_Code'])

print(df_final_merged['Total'].max())

print('\n')

print(df_final_merged.head())

print('\n')

print(df_final_merged.info)

print('\n')

print(df_final_merged.describe())

print('\n')

print(df_final_merged.dtypes)
# Out:
# 4079
#
#
#    ZCTA_Code                                           geometry  \
# 0      10280  MULTIPOLYGON (((-74.01858899999999 40.712201, ...
# 1      11358  MULTIPOLYGON (((-73.807514 40.762178999999996,...
# 2      11225  MULTIPOLYGON (((-73.96289399999999 40.663798, ...
# 3      11221  MULTIPOLYGON (((-73.948185 40.690242, -73.9453...
# 4      11411  MULTIPOLYGON (((-73.74864300000002 40.70158699...
#
#                                         polygon_geom  \
# 0  POLYGON ((-74.01858899999999 40.712201, -74.01...
# 1  POLYGON ((-73.807514 40.762178999999996, -73.8...
# 2  POLYGON ((-73.96289399999999 40.663798, -73.96...
# 3  POLYGON ((-73.948185 40.690242, -73.945349 40....
# 4  POLYGON ((-73.74864300000002 40.70158699999999...
#
#                                         centroid  \
# 0   POINT (-74.01690924352604 40.71025141632766)
# 1      POINT (-73.79669671875001 40.76080428125)
# 2  POINT (-73.95431249265435 40.663038155147255)
# 3   POINT (-73.92605128125001 40.69324903124999)
# 4       POINT (-73.7350738125 40.69432506249999)
#
#                                              geojson  Positive  Total  \
# 0  {"type": "Polygon", "coordinates": [[[-74.0185...        32    100
# 1  {"type": "Polygon", "coordinates": [[[-73.8075...       368    724
# 2  {"type": "Polygon", "coordinates": [[[-73.9628...       797   1309
# 3  {"type": "Polygon", "coordinates": [[[-73.9481...       788   1375
# 4  {"type": "Polygon", "coordinates": [[[-73.7486...       480    756
#
#    zcta_cum.perc_pos
# 0              32.00
# 1              50.83
# 2              60.89
# 3              57.31
# 4              63.49
#
#
# <bound method DataFrame.info of      ZCTA_Code                                           geometry  \
# 0        10280  MULTIPOLYGON (((-74.01858899999999 40.712201, ...
# 1        11358  MULTIPOLYGON (((-73.807514 40.762178999999996,...
# 2        11225  MULTIPOLYGON (((-73.96289399999999 40.663798, ...
# 3        11221  MULTIPOLYGON (((-73.948185 40.690242, -73.9453...
# 4        11411  MULTIPOLYGON (((-73.74864300000002 40.70158699...
# ..         ...                                                ...
# 172      10304  MULTIPOLYGON (((-74.12017399999999 40.58821599...
# 173      11423  MULTIPOLYGON (((-73.781161 40.729213, -73.7775...
# 174      11356  MULTIPOLYGON (((-73.858158 40.787034999999996,...
# 175      11435  MULTIPOLYGON (((-73.82556699999999 40.71615099...
# 176      11203  MULTIPOLYGON (((-73.947676 40.660297, -73.9426...
#
#                                           polygon_geom  \
# 0    POLYGON ((-74.01858899999999 40.712201, -74.01...
# 1    POLYGON ((-73.807514 40.762178999999996, -73.8...
# 2    POLYGON ((-73.96289399999999 40.663798, -73.96...
# 3    POLYGON ((-73.948185 40.690242, -73.945349 40....
# 4    POLYGON ((-73.74864300000002 40.70158699999999...
# ..                                                 ...
# 172  POLYGON ((-74.12017399999999 40.58821599999999...
# 173  POLYGON ((-73.781161 40.729213, -73.777575 40....
# 174  POLYGON ((-73.858158 40.787034999999996, -73.8...
# 175  POLYGON ((-73.82556699999999 40.71615099999999...
# 176  POLYGON ((-73.947676 40.660297, -73.942611 40....
#
#                                           centroid  \
# 0     POINT (-74.01690924352604 40.71025141632766)
# 1        POINT (-73.79669671875001 40.76080428125)
# 2    POINT (-73.95431249265435 40.663038155147255)
# 3     POINT (-73.92605128125001 40.69324903124999)
# 4         POINT (-73.7350738125 40.69432506249999)
# ..                                             ...
# 172   POINT (-74.09772625106777 40.59711801189746)
# 173         POINT (-73.7781975 40.726738499999996)
# 174   POINT (-73.84435509374998 40.78785178124999)
# 175   POINT (-73.81549712500001 40.71218312499999)
# 176  POINT (-73.93544918749998 40.650487187500005)
#
#                                                geojson  Positive  Total  \
# 0    {"type": "Polygon", "coordinates": [[[-74.0185...        32    100
# 1    {"type": "Polygon", "coordinates": [[[-73.8075...       368    724
# 2    {"type": "Polygon", "coordinates": [[[-73.9628...       797   1309
# 3    {"type": "Polygon", "coordinates": [[[-73.9481...       788   1375
# 4    {"type": "Polygon", "coordinates": [[[-73.7486...       480    756
# ..                                                 ...       ...    ...
# 172  {"type": "Polygon", "coordinates": [[[-74.1201...       973   1946
# 173  {"type": "Polygon", "coordinates": [[[-73.7811...       631   1023
# 174  {"type": "Polygon", "coordinates": [[[-73.8581...       351    621
# 175  {"type": "Polygon", "coordinates": [[[-73.8255...       980   1683
# 176  {"type": "Polygon", "coordinates": [[[-73.9476...      1298   2058
#
#      zcta_cum.perc_pos
# 0                32.00
# 1                50.83
# 2                60.89
# 3                57.31
# 4                63.49
# ..                 ...
# 172              50.00
# 173              61.68
# 174              56.52
# 175              58.23
# 176              63.07
#
# [177 rows x 8 columns]>
#
#
#           ZCTA_Code     Positive        Total  zcta_cum.perc_pos
# count    177.000000   177.000000   177.000000         177.000000
# mean   10810.378531   717.135593  1282.389831          53.382260
# std      578.173317   499.433467   804.820428           9.156191
# min    10001.000000    14.000000    54.000000          25.930000
# 25%    10301.000000   348.000000   647.000000          46.760000
# 50%    11109.000000   586.000000  1087.000000          55.510000
# 75%    11361.000000  1041.000000  1863.000000          60.690000
# max    11697.000000  2749.000000  4079.000000          75.900000
#
#
# ZCTA_Code              int64
# geometry              object
# polygon_geom          object
# centroid              object
# geojson               object
# Positive               int64
# Total                  int64
# zcta_cum.perc_pos    float64
# dtype: object

# %% [markdown]
# # Cast ZCTA_Code column to str

# %%
df_final_merged['ZCTA_Code']=df_final_merged['ZCTA_Code'].astype(str)

# %% [markdown]
# # Send df_final_merged to csv

# %%
df_final_merged.to_csv(my_path+'NYC-covid-map-dataframe.csv')

# %% [markdown]
# # Create a geojson file from df_final_merged with geo/coordinate data and COVID data

# %%
def df_to_geojson(df, properties, zcta='ZCTA_Code',gj='geojson'):
    geojson = {'type':'FeatureCollection','features':[]}
    for _, row in df.iterrows():
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':'',
                  'id':[]}
        feature['geometry']= json.loads(row[gj])
        feature['id']= row[zcta]
        for prop in properties:
            feature['properties'][prop] = row[prop]
        geojson['features'].append(feature)
    return geojson

cols=["Positive","Total",'ZCTA_Code']
geojson_dict = df_to_geojson(df_final_merged,properties=cols)
geojson_str = json.dumps(geojson_dict, indent=2)

output_filename = my_path+'NYC-covid-map-dataset.json'
with open(output_filename, 'w') as output_file:
    output_file.write('{}'.format(geojson_str))

# %% [markdown]
# # Read in geojson to inspect

# %%
with open(my_path+'NYC-covid-map-dataset.json') as file:
    ny_geojson = json.load(file)
    print(json.dumps(ny_geojson, indent=2))
# Out:
# {
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 32,
#         "Total": 100,
#         "ZCTA_Code": "10280"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -74.01858899999999,
#               40.712201
#             ],
#             [
#               -74.016508,
#               40.713224
#             ],
#             [
#               -74.01736799999999,
#               40.713378
#             ],
#             [
#               -74.016198,
#               40.714766999999995
#             ],
#             [
#               -74.01359699999999,
#               40.713623
#             ],
#             [
#               -74.014697,
#               40.709779
#             ],
#             [
#               -74.015956,
#               40.70668
#             ],
#             [
#               -74.016131,
#               40.706244
#             ],
#             [
#               -74.017575,
#               40.70684
#             ],
#             [
#               -74.018008,
#               40.705664999999996
#             ],
#             [
#               -74.016628,
#               40.704799
#             ],
#             [
#               -74.015678,
#               40.70125600000001
#             ],
#             [
#               -74.0142519151327,
#               40.7003146857495
#             ],
#             [
#               -74.0168,
#               40.701794
#             ],
#             [
#               -74.0194854329352,
#               40.70690774995101
#             ],
#             [
#               -74.01858899999999,
#               40.712201
#             ]
#           ]
#         ]
#       },
#       "id": "10280"
#     },
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 368,
#         "Total": 724,
#         "ZCTA_Code": "11358"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -73.807514,
#               40.762178999999996
#             ],
#             [
#               -73.80720699999999,
#               40.768294999999995
#             ],
#             [
#               -73.805356,
#               40.771094999999995
#             ],
#             [
#               -73.806153,
#               40.772209
#             ],
#             [
#               -73.804279,
#               40.772061
#             ],
#             [
#               -73.803985,
#               40.77419
#             ],
#             [
#               -73.803887,
#               40.774901
#             ],
#             [
#               -73.79271299999999,
#               40.773787999999996
#             ],
#             [
#               -73.791635,
#               40.774239
#             ],
#             [
#               -73.789309,
#               40.76970800000001
#             ],
#             [
#               -73.78516800000001,
#               40.761433
#             ],
#             [
#               -73.785902,
#               40.759748
#             ],
#             [
#               -73.784471,
#               40.759864
#             ],
#             [
#               -73.78008799999999,
#               40.752494
#             ],
#             [
#               -73.781212,
#               40.751507
#             ],
#             [
#               -73.792305,
#               40.748366
#             ],
#             [
#               -73.794815,
#               40.748422
#             ],
#             [
#               -73.795665,
#               40.750236
#             ],
#             [
#               -73.79729499999999,
#               40.749435000000005
#             ],
#             [
#               -73.798023,
#               40.748729999999995
#             ],
#             [
#               -73.80287799999999,
#               40.749783
#             ],
#             [
#               -73.807506,
#               40.750136999999995
#             ],
#             [
#               -73.809135,
#               40.750268999999996
#             ],
#             [
#               -73.807514,
#               40.762178999999996
#             ]
#           ]
#         ]
#       },
#       "id": "11358"
#     },
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 797,
#         "Total": 1309,
#         "ZCTA_Code": "11225"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -73.96289399999999,
#               40.663798
#             ],
#             [
#               -73.962429,
#               40.663125
#             ],
#             [
#               -73.960956,
#               40.663284999999995
#             ],
#             [
#               -73.962622,
#               40.671628999999996
#             ],
#             [
#               -73.957974,
#               40.670657
#             ],
#             [
#               -73.955269,
#               40.670125
#             ],
#             [
#               -73.94773099999999,
#               40.669705
#             ],
#             [
#               -73.947818,
#               40.668783999999995
#             ],
#             [
#               -73.948067,
#               40.666139
#             ],
#             [
#               -73.942528,
#               40.665838
#             ],
#             [
#               -73.942696,
#               40.664055
#             ],
#             [
#               -73.940029,
#               40.663021
#             ],
#             [
#               -73.942829,
#               40.662847
#             ],
#             [
#               -73.942611,
#               40.66061
#             ],
#             [
#               -73.947676,
#               40.660297
#             ],
#             [
#               -73.94726399999999,
#               40.656437
#             ],
#             [
#               -73.95309400000001,
#               40.656508
#             ],
#             [
#               -73.95934299999999,
#               40.655983
#             ],
#             [
#               -73.959861,
#               40.655635
#             ],
#             [
#               -73.9619,
#               40.654871
#             ],
#             [
#               -73.96317499999999,
#               40.655674999999995
#             ],
#             [
#               -73.962807,
#               40.656877
#             ],
#             [
#               -73.965025,
#               40.662172999999996
#             ],
#             [
#               -73.96289399999999,
#               40.663798
#             ]
#           ]
#         ]
#       },
#       "id": "11225"
#     },
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 788,
#         "Total": 1375,
#         "ZCTA_Code": "11221"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -73.948185,
#               40.690242
#             ],
#             [
#               -73.945349,
#               40.690567
#             ],
#             [
#               -73.945642,
#               40.692033
#             ],
#             [
#               -73.939971,
#               40.692683
#             ],
#             [
#               -73.937195,
#               40.693751999999996
#             ],
#             [
#               -73.937049,
#               40.693021
#             ],
#             [
#               -73.934134,
#               40.693355
#             ],
#             [
#               -73.934797,
#               40.696737
#             ],
#             [
#               -73.935222,
#               40.696985999999995
#             ],
#             [
#               -73.93400799999999,
#               40.697117999999996
#             ],
#             [
#               -73.927797,
#               40.699585
#             ],
#             [
#               -73.929035,
#               40.700289999999995
#             ],
#             [
#               -73.927588,
#               40.701761999999995
#             ],
#             [
#               -73.917818,
#               40.696208
#             ],
#             [
#               -73.91636799999999,
#               40.69768
#             ],
#             [
#               -73.913361,
#               40.695969999999996
#             ],
#             [
#               -73.911806,
#               40.697554
#             ],
#             [
#               -73.910303,
#               40.6967
#             ],
#             [
#               -73.91185999999999,
#               40.695115
#             ],
#             [
#               -73.908853,
#               40.693405
#             ],
#             [
#               -73.916046,
#               40.686071999999996
#             ],
#             [
#               -73.91804599999999,
#               40.687213
#             ],
#             [
#               -73.91799600000002,
#               40.686965
#             ],
#             [
#               -73.920495,
#               40.685928
#             ],
#             [
#               -73.92367,
#               40.685964
#             ],
#             [
#               -73.93789199999999,
#               40.684331
#             ],
#             [
#               -73.938223,
#               40.683893999999995
#             ],
#             [
#               -73.943962,
#               40.683600999999996
#             ],
#             [
#               -73.945056,
#               40.689102
#             ],
#             [
#               -73.947893,
#               40.688776
#             ],
#             [
#               -73.948185,
#               40.690242
#             ]
#           ]
#         ]
#       },
#       "id": "11221"
#     },
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 480,
#         "Total": 756,
#         "ZCTA_Code": "11411"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -73.74864300000002,
#               40.701586999999996
#             ],
#             [
#               -73.743307,
#               40.70296
#             ],
#             [
#               -73.74309099999999,
#               40.702397
#             ],
#             [
#               -73.738233,
#               40.701885
#             ],
#             [
#               -73.732354,
#               40.702419
#             ],
#             [
#               -73.727707,
#               40.701565
#             ],
#             [
#               -73.727516,
#               40.697196
#             ],
#             [
#               -73.726503,
#               40.696886
#             ],
#             [
#               -73.725926,
#               40.68622500000001
#             ],
#             [
#               -73.725798,
#               40.684354
#             ],
#             [
#               -73.725861,
#               40.683223
#             ],
#             [
#               -73.73222,
#               40.685120999999995
#             ],
#             [
#               -73.737585,
#               40.686408
#             ],
#             [
#               -73.74745,
#               40.689350999999995
#             ],
#             [
#               -73.74722,
#               40.689715
#             ],
#             [
#               -73.74812299999999,
#               40.690131
#             ],
#             [
#               -73.745283,
#               40.694115
#             ],
#             [
#               -73.74619,
#               40.696118999999996
#             ],
#             [
#               -73.74864300000002,
#               40.701586999999996
#             ]
#           ]
#         ]
#       },
#       "id": "11411"
#     },
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 782,
#         "Total": 1312,
#         "ZCTA_Code": "11233"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -73.93789199999999,
#               40.684331
#             ],
#             [
#               -73.92367,
#               40.685964
#             ],
#             [
#               -73.920495,
#               40.685928
#             ],
#             [
#               -73.91799600000002,
#               40.686965
#             ],
#             [
#               -73.91804599999999,
#               40.687213
#             ],
#             [
#               -73.916046,
#               40.686071999999996
#             ],
#             [
#               -73.904046,
#               40.67922
#             ],
#             [
#               -73.903466,
#               40.678897
#             ],
#             [
#               -73.904688,
#               40.677943
#             ],
#             [
#               -73.903475,
#               40.675506999999996
#             ],
#             [
#               -73.914873,
#               40.670533
#             ],
#             [
#               -73.92004399999999,
#               40.669137
#             ],
#             [
#               -73.918382,
#               40.669002
#             ],
#             [
#               -73.922753,
#               40.667097999999996
#             ],
#             [
#               -73.92438899999999,
#               40.666385
#             ],
#             [
#               -73.925539,
#               40.668493
#             ],
#             [
#               -73.924996,
#               40.674735999999996
#             ],
#             [
#               -73.93045699999999,
#               40.675818
#             ],
#             [
#               -73.929058,
#               40.679277
#             ],
#             [
#               -73.93435099999999,
#               40.679564
#             ],
#             [
#               -73.937398,
#               40.67973
#             ],
#             [
#               -73.938223,
#               40.683893999999995
#             ],
#             [
#               -73.93789199999999,
#               40.684331
#             ]
#           ]
#         ]
#       },
#       "id": "11233"
#     },
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 968,
#         "Total": 1567,
#         "ZCTA_Code": "11220"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -74.038336,
#               40.637074
#             ],
#             [
#               -74.03585910791371,
#               40.6407893381295
#             ],
#             [
#               -74.03351683155289,
#               40.6443027526705
#             ],
#             [
#               -74.03264399999999,
#               40.6438
#             ],
#             [
#               -74.030498,
#               40.6453
#             ],
#             [
#               -74.02825500000002,
#               40.644053
#             ],
#             [
#               -74.02606,
#               40.646260999999996
#             ],
#             [
#               -74.029294,
#               40.64874
#             ],
#             [
#               -74.025468,
#               40.646833
#             ],
#             [
#               -74.024065,
#               40.647597999999995
#             ],
#             [
#               -74.025637,
#               40.649753
#             ],
#             [
#               -74.024406,
#               40.650922
#             ],
#             [
#               -74.020877,
#               40.648742999999996
#             ],
#             [
#               -74.02145999999999,
#               40.648182
#             ],
#             [
#               -74.019256,
#               40.646853
#             ],
#             [
#               -74.01343,
#               40.652453
#             ],
#             [
#               -74.009402,
#               40.652758999999996
#             ],
#             [
#               -74.01055,
#               40.651634
#             ],
#             [
#               -74.006241,
#               40.649021999999995
#             ],
#             [
#               -74.006824,
#               40.648465
#             ],
#             [
#               -74.002415,
#               40.645809
#             ],
#             [
#               -74.002111,
#               40.646099
#             ],
#             [
#               -73.999931,
#               40.644306
#             ],
#             [
#               -73.997734,
#               40.643409999999996
#             ],
#             [
#               -73.99917599999999,
#               40.642026
#             ],
#             [
#               -74.003253,
#               40.638104
#             ],
#             [
#               -74.000525,
#               40.636455999999995
#             ],
#             [
#               -74.00124,
#               40.635978
#             ],
#             [
#               -74.003838,
#               40.637546
#             ],
#             [
#               -74.00796,
#               40.633584
#             ],
#             [
#               -74.00702299999999,
#               40.63211
#             ],
#             [
#               -74.00853699999999,
#               40.633027999999996
#             ],
#             [
#               -74.01097000000001,
#               40.63068200000001
#             ],
#             [
#               -74.01270199999999,
#               40.629024
#             ],
#             [
#               -74.012142,
#               40.628684
#             ],
#             [
#               -74.012846,
#               40.628656
#             ],
#             [
#               -74.016048,
#               40.631033
#             ],
#             [
#               -74.026039,
#               40.635740999999996
#             ],
#             [
#               -74.035958,
#               40.638821
#             ],
#             [
#               -74.03607099999999,
#               40.637305999999995
#             ],
#             [
#               -74.037245,
#               40.635985
#             ],
#             [
#               -74.03876862940801,
#               40.6357762179167
#             ],
#             [
#               -74.038336,
#               40.637074
#             ]
#           ]
#         ]
#       },
#       "id": "11220"
#     },
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 586,
#         "Total": 1139,
#         "ZCTA_Code": "10303"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -74.197,
#               40.632282
#             ],
#             [
#               -74.196027,
#               40.631563
#             ],
#             [
#               -74.19251799999999,
#               40.633364
#             ],
#             [
#               -74.1964546854975,
#               40.6353862362867
#             ],
#             [
#               -74.1918025434625,
#               40.6398274090899
#             ],
#             [
#               -74.1894,
#               40.642120999999996
#             ],
#             [
#               -74.1891166285585,
#               40.6422256218809
#             ],
#             [
#               -74.1868204209173,
#               40.6430733910176
#             ],
#             [
#               -74.1824082385683,
#               40.644702386564
#             ],
#             [
#               -74.180191,
#               40.645520999999995
#             ],
#             [
#               -74.1786904077589,
#               40.6454197481161
#             ],
#             [
#               -74.178874,
#               40.643093
#             ],
#             [
#               -74.178024,
#               40.642806
#             ],
#             [
#               -74.176724,
#               40.643772999999996
#             ],
#             [
#               -74.175763,
#               40.643543
#             ],
#             [
#               -74.17545199999999,
#               40.645116
#             ],
#             [
#               -74.17398937426769,
#               40.6450376609468
#             ],
#             [
#               -74.17018700000001,
#               40.642201
#             ],
#             [
#               -74.1544994311523,
#               40.6391799537161
#             ],
#             [
#               -74.15433,
#               40.637447
#             ],
#             [
#               -74.152732,
#               40.638838
#             ],
#             [
#               -74.149969,
#               40.637572000000006
#             ],
#             [
#               -74.1488612134467,
#               40.6393017310039
#             ],
#             [
#               -74.1430961731759,
#               40.639884617773
#             ],
#             [
#               -74.14518199999999,
#               40.634462
#             ],
#             [
#               -74.145668,
#               40.63147
#             ],
#             [
#               -74.14356699999999,
#               40.631878
#             ],
#             [
#               -74.1457,
#               40.630927
#             ],
#             [
#               -74.14546299999999,
#               40.627887
#             ],
#             [
#               -74.14614499999999,
#               40.62493
#             ],
#             [
#               -74.14876799999999,
#               40.625104
#             ],
#             [
#               -74.149614,
#               40.622793
#             ],
#             [
#               -74.151541,
#               40.621202
#             ],
#             [
#               -74.164068,
#               40.621921
#             ],
#             [
#               -74.164704,
#               40.619631999999996
#             ],
#             [
#               -74.167986,
#               40.620971
#             ],
#             [
#               -74.168725,
#               40.621209
#             ],
#             [
#               -74.174232,
#               40.619546
#             ],
#             [
#               -74.176157,
#               40.617796
#             ],
#             [
#               -74.178894,
#               40.61356800000001
#             ],
#             [
#               -74.18030999999999,
#               40.612185000000004
#             ],
#             [
#               -74.17847,
#               40.615575
#             ],
#             [
#               -74.176653,
#               40.620751999999996
#             ],
#             [
#               -74.176328,
#               40.623776
#             ],
#             [
#               -74.17766999999999,
#               40.625066
#             ],
#             [
#               -74.18377699999999,
#               40.628312
#             ],
#             [
#               -74.184815,
#               40.627508
#             ],
#             [
#               -74.185423,
#               40.628664
#             ],
#             [
#               -74.188206,
#               40.629021
#             ],
#             [
#               -74.189418,
#               40.630652
#             ],
#             [
#               -74.190463,
#               40.628873
#             ],
#             [
#               -74.192251,
#               40.628806999999995
#             ],
#             [
#               -74.19282799999999,
#               40.630948
#             ],
#             [
#               -74.19496900000001,
#               40.630959999999995
#             ],
#             [
#               -74.196699,
#               40.631876999999996
#             ],
#             [
#               -74.197,
#               40.632282
#             ]
#           ]
#         ]
#       },
#       "id": "10303"
#     },
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 685,
#         "Total": 1231,
#         "ZCTA_Code": "11367"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -73.84525,
#               40.740166
#             ],
#             [
#               -73.841925,
#               40.741763999999996
#             ],
#             [
#               -73.835925,
#               40.743500999999995
#             ],
#             [
#               -73.827083,
#               40.742642
#             ],
#             [
#               -73.82498,
#               40.743106
#             ],
#             [
#               -73.821201,
#               40.740921
#             ],
#             [
#               -73.81653000000001,
#               40.739601
#             ],
#             [
#               -73.815128,
#               40.739922
#             ],
#             [
#               -73.815057,
#               40.738987
#             ],
#             [
#               -73.813222,
#               40.73876
#             ],
#             [
#               -73.80941399999999,
#               40.738603
#             ],
#             [
#               -73.810482,
#               40.736992
#             ],
#             [
#               -73.81239099999999,
#               40.737066999999996
#             ],
#             [
#               -73.812122,
#               40.733748999999996
#             ],
#             [
#               -73.810687,
#               40.733681999999995
#             ],
#             [
#               -73.812279,
#               40.73222
#             ],
#             [
#               -73.810886,
#               40.727171999999996
#             ],
#             [
#               -73.809342,
#               40.720957
#             ],
#             [
#               -73.809786,
#               40.719722
#             ],
#             [
#               -73.80904,
#               40.719912
#             ],
#             [
#               -73.80860500000001,
#               40.71841500000001
#             ],
#             [
#               -73.811835,
#               40.717873
#             ],
#             [
#               -73.812118,
#               40.719062
#             ],
#             [
#               -73.819305,
#               40.717135999999996
#             ],
#             [
#               -73.820054,
#               40.716809999999995
#             ],
#             [
#               -73.82556699999999,
#               40.716150999999996
#             ],
#             [
#               -73.829684,
#               40.716945
#             ],
#             [
#               -73.83161199999999,
#               40.717831
#             ],
#             [
#               -73.83583899999999,
#               40.722533999999996
#             ],
#             [
#               -73.837768,
#               40.726697
#             ],
#             [
#               -73.839607,
#               40.729133
#             ],
#             [
#               -73.842748,
#               40.732113
#             ],
#             [
#               -73.844568,
#               40.735133
#             ],
#             [
#               -73.84525,
#               40.740166
#             ]
#           ]
#         ]
#       },
#       "id": "11367"
#     },
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 839,
#         "Total": 1399,
#         "ZCTA_Code": "11420"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -73.83589599999999,
#               40.675754
#             ],
#             [
#               -73.832078,
#               40.675261
#             ],
#             [
#               -73.83094,
#               40.67812
#             ],
#             [
#               -73.831746,
#               40.679536999999996
#             ],
#             [
#               -73.813592,
#               40.68471
#             ],
#             [
#               -73.80801699999999,
#               40.687059999999995
#             ],
#             [
#               -73.805891,
#               40.682897
#             ],
#             [
#               -73.80139299999999,
#               40.673117
#             ],
#             [
#               -73.80166,
#               40.666756
#             ],
#             [
#               -73.810322,
#               40.66708
#             ],
#             [
#               -73.811306,
#               40.664125
#             ],
#             [
#               -73.812067,
#               40.663031
#             ],
#             [
#               -73.81333699999999,
#               40.662805999999996
#             ],
#             [
#               -73.823008,
#               40.663835999999996
#             ],
#             [
#               -73.826832,
#               40.663709
#             ],
#             [
#               -73.83270499999999,
#               40.665406
#             ],
#             [
#               -73.83331199999999,
#               40.666759
#             ],
#             [
#               -73.836981,
#               40.674678
#             ],
#             [
#               -73.83589599999999,
#               40.675754
#             ]
#           ]
#         ]
#       },
#       "id": "11420"
#     },
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 317,
#         "Total": 605,
#         "ZCTA_Code": "10470"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -73.880484,
#               40.896803
#             ],
#             [
#               -73.879251,
#               40.899547
#             ],
#             [
#               -73.878189,
#               40.905983
#             ],
#             [
#               -73.877855,
#               40.905922
#             ],
#             [
#               -73.867876,
#               40.902983
#             ],
#             [
#               -73.864669,
#               40.901793
#             ],
#             [
#               -73.85931,
#               40.900479
#             ],
#             [
#               -73.859604,
#               40.902178
#             ],
#             [
#               -73.85830200000001,
#               40.902077
#             ],
#             [
#               -73.857199,
#               40.902878
#             ],
#             [
#               -73.857321,
#               40.905017
#             ],
#             [
#               -73.856324,
#               40.906166
#             ],
#             [
#               -73.85410399999999,
#               40.906679
#             ],
#             [
#               -73.854881,
#               40.90821700000001
#             ],
#             [
#               -73.852678,
#               40.909898999999996
#             ],
#             [
#               -73.851123,
#               40.910008999999995
#             ],
#             [
#               -73.853528,
#               40.907464999999995
#             ],
#             [
#               -73.850225,
#               40.907368
#             ],
#             [
#               -73.84532,
#               40.905581999999995
#             ],
#             [
#               -73.844728,
#               40.904731999999996
#             ],
#             [
#               -73.84572399999999,
#               40.904796000000005
#             ],
#             [
#               -73.847045,
#               40.90173
#             ],
#             [
#               -73.84955000000001,
#               40.903045
#             ],
#             [
#               -73.853434,
#               40.898115
#             ],
#             [
#               -73.855386,
#               40.898876
#             ],
#             [
#               -73.85624,
#               40.897625999999995
#             ],
#             [
#               -73.856194,
#               40.899187999999995
#             ],
#             [
#               -73.859258,
#               40.900338
#             ],
#             [
#               -73.862875,
#               40.895154
#             ],
#             [
#               -73.863559,
#               40.895376999999996
#             ],
#             [
#               -73.86368499999999,
#               40.894324999999995
#             ],
#             [
#               -73.867487,
#               40.888179
#             ],
#             [
#               -73.86921099999999,
#               40.883325
#             ],
#             [
#               -73.87092,
#               40.880258
#             ],
#             [
#               -73.874792,
#               40.880075
#             ],
#             [
#               -73.874675,
#               40.881563
#             ],
#             [
#               -73.878126,
#               40.882154
#             ],
#             [
#               -73.877918,
#               40.887212
#             ],
#             [
#               -73.88018699999999,
#               40.892129
#             ],
#             [
#               -73.879994,
#               40.89541
#             ],
#             [
#               -73.880484,
#               40.896803
#             ]
#           ]
#         ]
#       },
#       "id": "10470"
#     },
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 1459,
#         "Total": 2203,
#         "ZCTA_Code": "11691"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -73.789148,
#               40.597508999999995
#             ],
#             [
#               -73.78398899999999,
#               40.602104
#             ],
#             [
#               -73.783137,
#               40.60359
#             ],
#             [
#               -73.78394999999999,
#               40.60488
#             ],
#             [
#               -73.77935699999999,
#               40.609254
#             ],
#             [
#               -73.77526399999999,
#               40.609718
#             ],
#             [
#               -73.774129,
#               40.608747
#             ],
#             [
#               -73.774256,
#               40.607457
#             ],
#             [
#               -73.77603599999999,
#               40.602525
#             ],
#             [
#               -73.77703,
#               40.601666
#             ],
#             [
#               -73.778121,
#               40.60044
#             ],
#             [
#               -73.780138,
#               40.600713999999996
#             ],
#             [
#               -73.78200199999999,
#               40.598943
#             ],
#             [
#               -73.78014999999999,
#               40.597058
#             ],
#             [
#               -73.777399,
#               40.598777
#             ],
#             [
#               -73.776354,
#               40.600947999999995
#             ],
#             [
#               -73.77497199999999,
#               40.601744000000004
#             ],
#             [
#               -73.774204,
#               40.598994999999995
#             ],
#             [
#               -73.77305,
#               40.597876
#             ],
#             [
#               -73.768023,
#               40.598189
#             ],
#             [
#               -73.770982,
#               40.598894
#             ],
#             [
#               -73.77117700000001,
#               40.600404999999995
#             ],
#             [
#               -73.770186,
#               40.602748999999996
#             ],
#             [
#               -73.77056499999999,
#               40.604839999999996
#             ],
#             [
#               -73.769088,
#               40.609578
#             ],
#             [
#               -73.773971,
#               40.612113
#             ],
#             [
#               -73.773448,
#               40.613645999999996
#             ],
#             [
#               -73.766819,
#               40.614291
#             ],
#             [
#               -73.763454,
#               40.61369
#             ],
#             [
#               -73.760021,
#               40.611349
#             ],
#             [
#               -73.75473199999999,
#               40.610405
#             ],
#             [
#               -73.748216,
#               40.612010999999995
#             ],
#             [
#               -73.74694199999999,
#               40.611775
#             ],
#             [
#               -73.745633,
#               40.611756
#             ],
#             [
#               -73.74307,
#               40.607886
#             ],
#             [
#               -73.738151,
#               40.602709999999995
#             ],
#             [
#               -73.738309,
#               40.598208
#             ],
#             [
#               -73.73763699999999,
#               40.594415
#             ],
#             [
#               -73.739278,
#               40.594483
#             ],
#             [
#               -73.740827,
#               40.594614
#             ],
#             [
#               -73.746629,
#               40.594301
#             ],
#             [
#               -73.751158,
#               40.591806
#             ],
#             [
#               -73.751885,
#               40.591299
#             ],
#             [
#               -73.7552665240504,
#               40.5908624008346
#             ],
#             [
#               -73.755269,
#               40.590894999999996
#             ],
#             [
#               -73.7560282162845,
#               40.590889747778895
#             ],
#             [
#               -73.7675356211426,
#               40.5908101401152
#             ],
#             [
#               -73.7696436778067,
#               40.59079555668241
#             ],
#             [
#               -73.770231,
#               40.593975
#             ],
#             [
#               -73.774452,
#               40.592942
#             ],
#             [
#               -73.77947999999999,
#               40.592631999999995
#             ],
#             [
#               -73.77950299999999,
#               40.591094999999996
#             ],
#             [
#               -73.781425,
#               40.590771
#             ],
#             [
#               -73.781632,
#               40.592224
#             ],
#             [
#               -73.785062,
#               40.592200000000005
#             ],
#             [
#               -73.78337499999999,
#               40.592721999999995
#             ],
#             [
#               -73.783612,
#               40.595144999999995
#             ],
#             [
#               -73.784796,
#               40.597704
#             ],
#             [
#               -73.789148,
#               40.597508999999995
#             ]
#           ]
#         ]
#       },
#       "id": "11691"
#     },
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 759,
#         "Total": 1270,
#         "ZCTA_Code": "10455"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -73.920349,
#               40.814629
#             ],
#             [
#               -73.91923799999999,
#               40.81722
#             ],
#             [
#               -73.91745999999999,
#               40.81676100000001
#             ],
#             [
#               -73.918899,
#               40.817966999999996
#             ],
#             [
#               -73.917417,
#               40.821276999999995
#             ],
#             [
#               -73.912159,
#               40.819786
#             ],
#             [
#               -73.91189,
#               40.820256
#             ],
#             [
#               -73.910348,
#               40.819947
#             ],
#             [
#               -73.90531299999999,
#               40.817924999999995
#             ],
#             [
#               -73.90299,
#               40.820026999999996
#             ],
#             [
#               -73.902107,
#               40.818504999999995
#             ],
#             [
#               -73.900023,
#               40.818594999999995
#             ],
#             [
#               -73.895428,
#               40.815844999999996
#             ],
#             [
#               -73.89719699999999,
#               40.813514
#             ],
#             [
#               -73.902988,
#               40.809363999999995
#             ],
#             [
#               -73.907833,
#               40.806762
#             ],
#             [
#               -73.90496,
#               40.808531
#             ],
#             [
#               -73.910366,
#               40.809644999999996
#             ],
#             [
#               -73.910693,
#               40.808809
#             ],
#             [
#               -73.915178,
#               40.810427
#             ],
#             [
#               -73.914474,
#               40.811651
#             ],
#             [
#               -73.91926699999999,
#               40.81372700000001
#             ],
#             [
#               -73.92011900000001,
#               40.812894
#             ],
#             [
#               -73.922088,
#               40.813731
#             ],
#             [
#               -73.920349,
#               40.814629
#             ]
#           ]
#         ]
#       },
#       "id": "10455"
#     },
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 233,
#         "Total": 517,
#         "ZCTA_Code": "10014"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -74.015728,
#               40.725423
#             ],
#             [
#               -74.01182,
#               40.725083
#             ],
#             [
#               -74.011653,
#               40.725907
#             ],
#             [
#               -74.015219,
#               40.726335999999996
#             ],
#             [
#               -74.011569,
#               40.726445
#             ],
#             [
#               -74.011376,
#               40.728232999999996
#             ],
#             [
#               -74.01435699999999,
#               40.728612
#             ],
#             [
#               -74.014072,
#               40.730689
#             ],
#             [
#               -74.011164,
#               40.730444
#             ],
#             [
#               -74.01420399999999,
#               40.731505
#             ],
#             [
#               -74.011077,
#               40.731449
#             ],
#             [
#               -74.01065899999999,
#               40.736022
#             ],
#             [
#               -74.01300700000002,
#               40.73612
#             ],
#             [
#               -74.010578,
#               40.736971
#             ],
#             [
#               -74.01039399999999,
#               40.739135999999995
#             ],
#             [
#               -74.01166200000002,
#               40.739224
#             ],
#             [
#               -74.011456,
#               40.740818
#             ],
#             [
#               -74.009664,
#               40.740741
#             ],
#             [
#               -74.009366,
#               40.742298999999996
#             ],
#             [
#               -74.012331,
#               40.742618
#             ],
#             [
#               -74.009331,
#               40.742571999999996
#             ],
#             [
#               -74.008204,
#               40.742148
#             ],
#             [
#               -74.007705,
#               40.742833999999995
#             ],
#             [
#               -74.00486099999999,
#               40.741642
#             ],
#             [
#               -74.005366,
#               40.740945
#             ],
#             [
#               -74.002523,
#               40.739753
#             ],
#             [
#               -73.999555,
#               40.733610999999996
#             ],
#             [
#               -74.000954,
#               40.731705999999996
#             ],
#             [
#               -74.00315499999999,
#               40.727664
#             ],
#             [
#               -74.00372999999999,
#               40.72625
#             ],
#             [
#               -74.005545,
#               40.727157
#             ],
#             [
#               -74.00962299999999,
#               40.727557000000004
#             ],
#             [
#               -74.011978,
#               40.724333
#             ],
#             [
#               -74.01599,
#               40.724765999999995
#             ],
#             [
#               -74.015728,
#               40.725423
#             ]
#           ]
#         ]
#       },
#       "id": "10014"
#     },
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 525,
#         "Total": 898,
#         "ZCTA_Code": "11427"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -73.766244,
#               40.726403
#             ],
#             [
#               -73.762063,
#               40.725986
#             ],
#             [
#               -73.75671,
#               40.726178999999995
#             ],
#             [
#               -73.762245,
#               40.729344
#             ],
#             [
#               -73.765551,
#               40.732544
#             ],
#             [
#               -73.7637,
#               40.732864
#             ],
#             [
#               -73.746541,
#               40.735777999999996
#             ],
#             [
#               -73.745947,
#               40.734168
#             ],
#             [
#               -73.74661499999999,
#               40.733394
#             ],
#             [
#               -73.746738,
#               40.732583000000005
#             ],
#             [
#               -73.743065,
#               40.735465
#             ],
#             [
#               -73.740291,
#               40.738517
#             ],
#             [
#               -73.739224,
#               40.739684
#             ],
#             [
#               -73.732325,
#               40.743645
#             ],
#             [
#               -73.72672899999999,
#               40.740784999999995
#             ],
#             [
#               -73.726112,
#               40.736382
#             ],
#             [
#               -73.727014,
#               40.735582
#             ],
#             [
#               -73.726366,
#               40.733455
#             ],
#             [
#               -73.73098499999999,
#               40.732665
#             ],
#             [
#               -73.732168,
#               40.729155
#             ],
#             [
#               -73.733617,
#               40.727934
#             ],
#             [
#               -73.740702,
#               40.729532999999996
#             ],
#             [
#               -73.739311,
#               40.728167
#             ],
#             [
#               -73.752334,
#               40.720262
#             ],
#             [
#               -73.757257,
#               40.718139
#             ],
#             [
#               -73.75764199999999,
#               40.717971
#             ],
#             [
#               -73.759216,
#               40.719198999999996
#             ],
#             [
#               -73.759441,
#               40.721063
#             ],
#             [
#               -73.76153099999999,
#               40.722992
#             ],
#             [
#               -73.76479599999999,
#               40.724683999999996
#             ],
#             [
#               -73.766244,
#               40.726403
#             ]
#           ]
#         ]
#       },
#       "id": "11427"
#     },
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 302,
#         "Total": 590,
#         "ZCTA_Code": "11361"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -73.789309,
#               40.76970800000001
#             ],
#             [
#               -73.778858,
#               40.772799
#             ],
#             [
#               -73.77481399999999,
#               40.773672999999995
#             ],
#             [
#               -73.774475,
#               40.772102
#             ],
#             [
#               -73.77348599999999,
#               40.772306
#             ],
#             [
#               -73.773838,
#               40.773846
#             ],
#             [
#               -73.771581,
#               40.774306
#             ],
#             [
#               -73.769842,
#               40.77261
#             ],
#             [
#               -73.765452,
#               40.773579999999995
#             ],
#             [
#               -73.7635021041273,
#               40.7728644105616
#             ],
#             [
#               -73.75888499999999,
#               40.769118
#             ],
#             [
#               -73.75864299999999,
#               40.767357
#             ],
#             [
#               -73.75377,
#               40.765305
#             ],
#             [
#               -73.75920599999999,
#               40.764320999999995
#             ],
#             [
#               -73.758363,
#               40.763497
#             ],
#             [
#               -73.758001,
#               40.76038
#             ],
#             [
#               -73.760089,
#               40.759952
#             ],
#             [
#               -73.759545,
#               40.759139999999995
#             ],
#             [
#               -73.75762999999999,
#               40.760109
#             ],
#             [
#               -73.757319,
#               40.759035999999995
#             ],
#             [
#               -73.75902099999999,
#               40.758348
#             ],
#             [
#               -73.760378,
#               40.755843
#             ],
#             [
#               -73.758467,
#               40.753301
#             ],
#             [
#               -73.75944,
#               40.752403
#             ],
#             [
#               -73.761927,
#               40.755773
#             ],
#             [
#               -73.761856,
#               40.756516999999995
#             ],
#             [
#               -73.768316,
#               40.755466
#             ],
#             [
#               -73.77210000000001,
#               40.754481999999996
#             ],
#             [
#               -73.776178,
#               40.752894
#             ],
#             [
#               -73.779806,
#               40.751895
#             ],
#             [
#               -73.78008799999999,
#               40.752494
#             ],
#             [
#               -73.784471,
#               40.759864
#             ],
#             [
#               -73.785902,
#               40.759748
#             ],
#             [
#               -73.78516800000001,
#               40.761433
#             ],
#             [
#               -73.789309,
#               40.76970800000001
#             ]
#           ]
#         ]
#       },
#       "id": "11361"
#     },
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 1880,
#         "Total": 4079,
#         "ZCTA_Code": "10314"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -74.21326368101151,
#               40.5586027264388
#             ],
# ...
#             ],
#             [
#               -74.087733,
#               40.596011999999995
#             ],
#             [
#               -74.089249,
#               40.594108999999996
#             ],
#             [
#               -74.09849299999999,
#               40.587106
#             ],
#             [
#               -74.10207900000002,
#               40.588741
#             ],
#             [
#               -74.100883,
#               40.590179
#             ],
#             [
#               -74.107781,
#               40.584353
#             ],
#             [
#               -74.11392099999999,
#               40.580506
#             ],
#             [
#               -74.11542299999999,
#               40.578631
#             ],
#             [
#               -74.11749,
#               40.577756
#             ],
#             [
#               -74.11828899999999,
#               40.578192
#             ],
#             [
#               -74.119149,
#               40.581508
#             ],
#             [
#               -74.12311199999999,
#               40.58510400000001
#             ],
#             [
#               -74.12017399999999,
#               40.588215999999996
#             ]
#           ],
#           [
#             [
#               -74.093525,
#               40.612916999999996
#             ],
#             [
#               -74.09358499999999,
#               40.612792
#             ],
#             [
#               -74.094686,
#               40.612181
#             ],
#             [
#               -74.09299399999999,
#               40.611442
#             ],
#             [
#               -74.091325,
#               40.611655
#             ],
#             [
#               -74.090983,
#               40.612066
#             ],
#             [
#               -74.092698,
#               40.61261
#             ],
#             [
#               -74.093525,
#               40.612916999999996
#             ]
#           ]
#         ]
#       },
#       "id": "10304"
#     },
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 631,
#         "Total": 1023,
#         "ZCTA_Code": "11423"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -73.781161,
#               40.729213
#             ],
#             [
#               -73.777575,
#               40.730193
#             ],
#             [
#               -73.775234,
#               40.725238
#             ],
#             [
#               -73.778038,
#               40.723284
#             ],
#             [
#               -73.779066,
#               40.724964
#             ],
#             [
#               -73.779853,
#               40.726403
#             ],
#             [
#               -73.780799,
#               40.728425
#             ],
#             [
#               -73.781161,
#               40.729213
#             ]
#           ],
#           [
#             [
#               -73.783135,
#               40.706298
#             ],
#             [
#               -73.779975,
#               40.707051
#             ],
#             [
#               -73.77937299999999,
#               40.707812
#             ],
#             [
#               -73.78035899999999,
#               40.708464
#             ],
#             [
#               -73.780309,
#               40.709001
#             ],
#             [
#               -73.782625,
#               40.712938
#             ],
#             [
#               -73.77357099999999,
#               40.71512
#             ],
#             [
#               -73.775836,
#               40.717666
#             ],
#             [
#               -73.775511,
#               40.719094
#             ],
#             [
#               -73.777385,
#               40.72244200000001
#             ],
#             [
#               -73.77359,
#               40.724742
#             ],
#             [
#               -73.766244,
#               40.726403
#             ],
#             [
#               -73.76479599999999,
#               40.724683999999996
#             ],
#             [
#               -73.76153099999999,
#               40.722992
#             ],
#             [
#               -73.759441,
#               40.721063
#             ],
#             [
#               -73.759216,
#               40.719198999999996
#             ],
#             [
#               -73.75764199999999,
#               40.717971
#             ],
#             [
#               -73.755579,
#               40.71433
#             ],
#             [
#               -73.754701,
#               40.71471
#             ],
#             [
#               -73.75370800000002,
#               40.713325
#             ],
#             [
#               -73.75318399999999,
#               40.712055
#             ],
#             [
#               -73.75408,
#               40.711841
#             ],
#             [
#               -73.753356,
#               40.710101
#             ],
#             [
#               -73.764564,
#               40.7074
#             ],
#             [
#               -73.767251,
#               40.706313
#             ],
#             [
#               -73.774181,
#               40.705087
#             ],
#             [
#               -73.775465,
#               40.705318999999996
#             ],
#             [
#               -73.77470799999999,
#               40.707333
#             ],
#             [
#               -73.771008,
#               40.708724
#             ],
#             [
#               -73.776501,
#               40.707238000000004
#             ],
#             [
#               -73.781837,
#               40.706171999999995
#             ],
#             [
#               -73.783135,
#               40.706298
#             ]
#           ]
#         ]
#       },
#       "id": "11423"
#     },
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 351,
#         "Total": 621,
#         "ZCTA_Code": "11356"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -73.858158,
#               40.787034999999996
#             ],
#             [
#               -73.856616,
#               40.786749
#             ],
#             [
#               -73.855974,
#               40.787666
#             ],
#             [
#               -73.85325399999999,
#               40.787875
#             ],
#             [
#               -73.85480199999999,
#               40.788844999999995
#             ],
#             [
#               -73.854503,
#               40.790183
#             ],
#             [
#               -73.85266399999999,
#               40.791256
#             ],
#             [
#               -73.85377,
#               40.792336
#             ],
#             [
#               -73.852659,
#               40.79492
#             ],
#             [
#               -73.849341,
#               40.793372999999995
#             ],
#             [
#               -73.84871,
#               40.795415999999996
#             ],
#             [
#               -73.846245,
#               40.796161999999995
#             ],
#             [
#               -73.84370799999999,
#               40.794886
#             ],
#             [
#               -73.84012,
#               40.796882
#             ],
#             [
#               -73.83842899999999,
#               40.798376
#             ],
#             [
#               -73.83843399999999,
#               40.796786999999995
#             ],
#             [
#               -73.83663299999999,
#               40.792516
#             ],
#             [
#               -73.837426,
#               40.791391
#             ],
#             [
#               -73.837272,
#               40.789063999999996
#             ],
#             [
#               -73.835585,
#               40.789562
#             ],
#             [
#               -73.83382999999999,
#               40.788522
#             ],
#             [
#               -73.831976,
#               40.789449999999995
#             ],
#             [
#               -73.831017,
#               40.789339
#             ],
#             [
#               -73.830589,
#               40.784641
#             ],
#             [
#               -73.82690199999999,
#               40.784652
#             ],
#             [
#               -73.826785,
#               40.781667999999996
#             ],
#             [
#               -73.825285,
#               40.781697
#             ],
#             [
#               -73.826235,
#               40.779921
#             ],
#             [
#               -73.82852799999999,
#               40.776007
#             ],
#             [
#               -73.831593,
#               40.77256
#             ],
#             [
#               -73.833428,
#               40.771434
#             ],
#             [
#               -73.836332,
#               40.778529
#             ],
#             [
#               -73.83886199999999,
#               40.778617
#             ],
#             [
#               -73.838967,
#               40.776774
#             ],
#             [
#               -73.839983,
#               40.776503
#             ],
#             [
#               -73.849038,
#               40.777004999999996
#             ],
#             [
#               -73.849773,
#               40.778728
#             ],
#             [
#               -73.849845,
#               40.781593
#             ],
#             [
#               -73.84925299999999,
#               40.782264999999995
#             ],
#             [
#               -73.85538799999999,
#               40.782075999999996
#             ],
#             [
#               -73.855451,
#               40.783143
#             ],
#             [
#               -73.85808300000001,
#               40.783724
#             ],
#             [
#               -73.859089,
#               40.785531999999996
#             ],
#             [
#               -73.858158,
#               40.787034999999996
#             ]
#           ]
#         ]
#       },
#       "id": "11356"
#     },
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 980,
#         "Total": 1683,
#         "ZCTA_Code": "11435"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -73.82556699999999,
#               40.716150999999996
#             ],
#             [
#               -73.820054,
#               40.716809999999995
#             ],
#             [
#               -73.819305,
#               40.717135999999996
#             ],
#             [
#               -73.812118,
#               40.719062
#             ],
#             [
#               -73.811835,
#               40.717873
#             ],
#             [
#               -73.811815,
#               40.716882
#             ],
#             [
#               -73.808235,
#               40.717237999999995
#             ],
#             [
#               -73.807774,
#               40.715716
#             ],
#             [
#               -73.810221,
#               40.715706999999995
#             ],
#             [
#               -73.809834,
#               40.712812
#             ],
#             [
#               -73.806949,
#               40.707367000000005
#             ],
#             [
#               -73.80564799999999,
#               40.704671999999995
#             ],
#             [
#               -73.804129,
#               40.70146
#             ],
#             [
#               -73.802409,
#               40.701851999999995
#             ],
#             [
#               -73.803962,
#               40.701052
#             ],
#             [
#               -73.802101,
#               40.700643
#             ],
#             [
#               -73.802768,
#               40.699104999999996
#             ],
#             [
#               -73.800936,
#               40.694424999999995
#             ],
#             [
#               -73.798277,
#               40.691933999999996
#             ],
#             [
#               -73.796101,
#               40.689282
#             ],
#             [
#               -73.794153,
#               40.687751999999996
#             ],
#             [
#               -73.794371,
#               40.686913
#             ],
#             [
#               -73.794578,
#               40.686107
#             ],
#             [
#               -73.805891,
#               40.682897
#             ],
#             [
#               -73.80801699999999,
#               40.687059999999995
#             ],
#             [
#               -73.810749,
#               40.691917
#             ],
#             [
#               -73.81371899999999,
#               40.697153
#             ],
#             [
#               -73.81647699999999,
#               40.70245
#             ],
#             [
#               -73.818313,
#               40.706164
#             ],
#             [
#               -73.820662,
#               40.709869
#             ],
#             [
#               -73.824304,
#               40.713869
#             ],
#             [
#               -73.82471699999999,
#               40.714507
#             ],
#             [
#               -73.825921,
#               40.715928
#             ],
#             [
#               -73.82556699999999,
#               40.716150999999996
#             ]
#           ]
#         ]
#       },
#       "id": "11435"
#     },
#     {
#       "type": "feature",
#       "properties": {
#         "Positive": 1298,
#         "Total": 2058,
#         "ZCTA_Code": "11203"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -73.947676,
#               40.660297
#             ],
#             [
#               -73.942611,
#               40.66061
#             ],
#             [
#               -73.942829,
#               40.662847
#             ],
#             [
#               -73.940029,
#               40.663021
#             ],
#             [
#               -73.931607,
#               40.663557
#             ],
#             [
#               -73.931556,
#               40.662756
#             ],
#             [
#               -73.928193,
#               40.660177
#             ],
#             [
#               -73.927255,
#               40.659338
#             ],
#             [
#               -73.927201,
#               40.658536999999995
#             ],
#             [
#               -73.921776,
#               40.654424000000006
#             ],
#             [
#               -73.920581,
#               40.650707
#             ],
#             [
#               -73.919951,
#               40.644707
#             ],
#             [
#               -73.92087099999999,
#               40.643997999999996
#             ],
#             [
#               -73.921741,
#               40.643381999999995
#             ],
#             [
#               -73.921627,
#               40.642806
#             ],
#             [
#               -73.92067399999999,
#               40.642672
#             ],
#             [
#               -73.91972899999999,
#               40.642725
#             ],
#             [
#               -73.921609,
#               40.641687
#             ],
#             [
#               -73.922207,
#               40.641065
#             ],
#             [
#               -73.92332700000001,
#               40.639900000000004
#             ],
#             [
#               -73.926082,
#               40.638163
#             ],
#             [
#               -73.93158,
#               40.635391
#             ],
#             [
#               -73.93223499999999,
#               40.634963
#             ],
#             [
#               -73.934395,
#               40.634827
#             ],
#             [
#               -73.93536,
#               40.634767
#             ],
#             [
#               -73.93560699999999,
#               40.637038
#             ],
#             [
#               -73.937512,
#               40.63692100000001
#             ],
#             [
#               -73.93776199999999,
#               40.639258999999996
#             ],
#             [
#               -73.942503,
#               40.638965
#             ],
#             [
#               -73.94265100000001,
#               40.640344000000006
#             ],
#             [
#               -73.94650899999999,
#               40.640104
#             ],
#             [
#               -73.947059,
#               40.64525
#             ],
#             [
#               -73.947467,
#               40.649038999999995
#             ],
#             [
#               -73.946479,
#               40.649100000000004
#             ],
#             [
#               -73.947159,
#               40.65559400000001
#             ],
#             [
#               -73.94726399999999,
#               40.656437
#             ],
#             [
#               -73.947676,
#               40.660297
#             ]
#           ]
#         ]
#       },
#       "id": "11203"
#     }
#   ]
# }
